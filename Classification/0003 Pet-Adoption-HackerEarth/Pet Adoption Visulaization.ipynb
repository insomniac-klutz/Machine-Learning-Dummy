# %%
#Primary  Modules
import pandas as pd
import numpy as np

#Visulaization Tools
import seaborn as sns
import matplotlib.pyplot as plt

#Data Object Output

import pickle
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Import Data

train_data=pd.read_pickle(r"/content/drive/My Drive/Colab Data/Pet Adoption/basic_train.pickle")
test_data=pd.read_pickle(r"/content/drive/My Drive/Colab Data/Pet Adoption/basic_train.pickle")

# %%
plt.figure(figsize=(25,80))
p=sns.catplot(x='year_i',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='year_l',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='month_i',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='month_l',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='diff',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='year_i',y='pet_category',data=train_data)

# %%
p=sns.catplot(x='year_l',y='pet_category',data=train_data)

# %%
p=sns.catplot(x='month_i',y='pet_category',data=train_data)

# %%
p=sns.catplot(x='month_l',y='pet_category',data=train_data)

# %%
p=sns.catplot(x='diff',y='pet_category',data=train_data)

# %%
p=sns.catplot(x='diff',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='condition',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='condition',y='pet_category',data=train_data)

# %%
p=sns.catplot(x='X1',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='X2',y='pet_category',data=train_data)

# %%
p=sns.catplot(x='X2',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='X1',y='pet_category',data=train_data)

# %%
combine=[test_data,train_data]
for dataset in combine:
    dataset['X*'] = dataset['X1']*10+dataset['X2']

# %%
p=sns.catplot(x='X*',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='X*',y='pet_category',data=train_data)

# %%
p=sns.violinplot(x='pet_category',y='length(m)',data=train_data)

# %%
p=sns.violinplot(x='pet_category',y='height(cm)',data=train_data)

# %%
plt.figure(figsize=(17,8))
sns.heatmap(train_data.corr(), cmap="binary")

# %%
# Import Modified Data

train_data=pd.read_pickle(r"/content/drive/My Drive/Colab Data/Pet Adoption/modified_train.pickle")
test_data=pd.read_pickle(r"/content/drive/My Drive/Colab Data/Pet Adoption/modified_train.pickle")

# %%
p=sns.catplot(x='color_tag',y='breed_category',data=train_data)

# %%
p=sns.violinplot(x='pet_category',y='l&h',data=train_data)

# %%
p=sns.catplot(x='color_tag',y='pet_category',data=train_data)

# %%
p=sns.catplot(x='l&h',y='breed_category',data=train_data)

# %%
p=sns.catplot(x='l&h',y='pet_category',data=train_data)

# %%
p=sns.catplot(x='height',y='breed_category',data=train_data)

# %%
sns.catplot(x='pet_pred',y='pet_category',data=train_data)

# %%
sns.catplot(x='pet_pred',y='breed_category',data=train_data)

# %%
sns.catplot(x='diff_map',y='breed_category',data=train_data)

# %%
sns.catplot(x='diff_map',y='pet_category',data=train_data)
